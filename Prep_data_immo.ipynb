# %% [markdown]
# <a href="https://colab.research.google.com/github/nathan311/Learn-Python/blob/main/Prep_data_immo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data_2020 = pd.read_csv('https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-070941/valeursfoncieres-2020.txt.zip', sep="|")
data_2020
# Out:
# <ipython-input-6-132051888b08>:3: DtypeWarning: Columns (18,23,24,26,28,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2020 = pd.read_csv('https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-070941/valeursfoncieres-2020.txt.zip', sep="|")
#          Identifiant de document  Reference document  1 Articles CGI  \
# 0                            NaN                 NaN             NaN
# 1                            NaN                 NaN             NaN
# 2                            NaN                 NaN             NaN
# 3                            NaN                 NaN             NaN
# 4                            NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 3522095                      NaN                 NaN             NaN
# 3522096                      NaN                 NaN             NaN
# ...

# %%
data_toulouse = data_2020[data_2020['Commune'].str.contains("TOULOUSE", na=False)]
data_toulouse
# Out:
#          Identifiant de document  Reference document  1 Articles CGI  \
# 983067                       NaN                 NaN             NaN
# 983068                       NaN                 NaN             NaN
# 983069                       NaN                 NaN             NaN
# 983070                       NaN                 NaN             NaN
# 983071                       NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 1446481                      NaN                 NaN             NaN
# 1446482                      NaN                 NaN             NaN
# 1446483                      NaN                 NaN             NaN
# 1446484                      NaN                 NaN             NaN
# 1446485                      NaN                 NaN             NaN
#
#          2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# ...

# %%
data_toulouse['Commune'].value_counts()
# Out:
# Commune
# TOULOUSE               28303
# VIEILLE TOULOUSE          74
# TOULOUSE-LE-CHATEAU       10
# Name: count, dtype: int64

# %%
toulouse = ['TOULOUSE']

# %%
data_toulouse = data_2020[data_2020['Commune'].isin(toulouse)]
data_toulouse.head()
# Out:
#         Identifiant de document  Reference document  1 Articles CGI  \
# 983067                      NaN                 NaN             NaN
# 983068                      NaN                 NaN             NaN
# 983069                      NaN                 NaN             NaN
# 983070                      NaN                 NaN             NaN
# 983071                      NaN                 NaN             NaN
#
#         2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 983067             NaN             NaN             NaN             NaN
# 983068             NaN             NaN             NaN             NaN
# 983069             NaN             NaN             NaN             NaN
# 983070             NaN             NaN             NaN             NaN
# 983071             NaN             NaN             NaN             NaN
#
#         No disposition Date mutation Nature mutation  ...  \
# 983067               2    06/01/2020           Vente  ...
# ...

# %%
data_toulouse['Commune'].value_counts()
# Out:
# Commune
# TOULOUSE    28303
# Name: count, dtype: int64

# %%
data_toulouse.shape
# Out:
# (28303, 43)

# %%
data_toulouse.isnull().sum()
# Out:
# Identifiant de document       28303
# Reference document            28303
# 1 Articles CGI                28303
# 2 Articles CGI                28303
# 3 Articles CGI                28303
# 4 Articles CGI                28303
# 5 Articles CGI                28303
# No disposition                    0
# Date mutation                     0
# Nature mutation                   0
# Valeur fonciere                  15
# No voie                        2116
# B/T/Q                         26807
# Type de voie                   1185
# Code voie                       386
# Voie                            386
# Code postal                     409
# Commune                           0
# Code departement                  0
# Code commune                      0
# Prefixe de section                0
# Section                           0
# No plan                           0
# No Volume                     28230
# 1er lot                        4375
# Surface Carrez du 1er lot     24567
# ...

# %%
data_toulouse = data_toulouse.drop(['Reference document','1 Articles CGI','2 Articles CGI',
                                      '3 Articles CGI','4 Articles CGI','5 Articles CGI','Identifiant local','No Volume','B/T/Q',
                                      'Surface Carrez du 1er lot','2eme lot','Surface Carrez du 2eme lot','3eme lot',
                                      'Surface Carrez du 3eme lot','4eme lot','Surface Carrez du 4eme lot','5eme lot',
                                      'Surface Carrez du 5eme lot','Nature culture','Nature culture speciale','Surface terrain'], axis=1)
data_toulouse.isnull().sum()
# Out:
# Identifiant de document      28303
# No disposition                   0
# Date mutation                    0
# Nature mutation                  0
# Valeur fonciere                 15
# No voie                       2116
# Type de voie                  1185
# Code voie                      386
# Voie                           386
# Code postal                    409
# Commune                          0
# Code departement                 0
# Code commune                     0
# Prefixe de section               0
# Section                          0
# No plan                          0
# 1er lot                       4375
# Nombre de lots                   0
# Code type local               6220
# Type local                    6220
# Surface reelle bati           6227
# Nombre pieces principales     6227
# dtype: int64

# %%
# %time

#lien data gouv https://www.data.gouv.fr/en/datasets/demandes-de-valeurs-foncieres/
#faq https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20191030-171734/faq.pdf
#dictionnaire de données https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20191220-102114/notice-descriptive-du-fichier-dvf.pdf
import pandas as pd
from tqdm.notebook import tqdm

url_dict = {
    '2024':'https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-071049/valeursfoncieres-2024-s1.txt.zip',
    '2023':'https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-071041/valeursfoncieres-2023.txt.zip',
    '2022':'https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-071010/valeursfoncieres-2022.txt.zip',
    '2021':'https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-070955/valeursfoncieres-2021.txt.zip',
    '2020':'https://static.data.gouv.fr/resources/demandes-de-valeurs-foncieres/20241008-070941/valeursfoncieres-2020.txt.zip'
}
def get_subsample():
    data_all_year=[]
    for year,url in tqdm(url_dict.items()):
        print(f'----------STARTING YEAR {year}----------')
        data_ = pd.read_csv(url, sep="|")
        data_ = data_.drop(['Reference document','1 Articles CGI','2 Articles CGI',
                                      '3 Articles CGI','4 Articles CGI','5 Articles CGI','Identifiant local','No Volume','B/T/Q',
                                      'Surface Carrez du 1er lot','2eme lot','Surface Carrez du 2eme lot','3eme lot',
                                      'Surface Carrez du 3eme lot','4eme lot','Surface Carrez du 4eme lot','5eme lot',
                                      'Surface Carrez du 5eme lot','Nature culture','Nature culture speciale','Surface terrain'], axis=1)

        print('Shape from import: ',data_.shape)

        toulouse_list_arrondissement = ['TOULOUSE']

        data_toulouse = data_[data_['Commune'].isin(toulouse_list_arrondissement)]
        print('Shape after subsample: ',data_toulouse.shape)
        print(f'\n Sampling of {round((data_toulouse.shape[0]/data_.shape[0])*100,2)} % of the original dataframe \n')
        del data_
        data_toulouse['year'] = year
        data_all_year.append(data_toulouse)
        del data_toulouse
        print(f'----------YEAR {year} DONE---------- \n')

    print('STARTING CONCATENATING')
    df = pd.concat(data_all_year)
    print('CONCATENING DONE')
    return df

df = get_subsample()
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.44 µs
#   0%|          | 0/5 [00:00<?, ?it/s]
# ----------STARTING YEAR 2024----------
# <ipython-input-27-1520f068e517>:20: DtypeWarning: Columns (14,18,23,24,26,28,30,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_ = pd.read_csv(url, sep="|")
# Shape from import:  (1566643, 22)
# Shape after subsample:  (9461, 22)
#
#  Sampling of 0.6 % of the original dataframe
#
# ----------YEAR 2024 DONE----------
#
# ----------STARTING YEAR 2023----------
# <ipython-input-27-1520f068e517>:20: DtypeWarning: Columns (14,18,23,24,26,28,31,32,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_ = pd.read_csv(url, sep="|")
# Shape from import:  (3799407, 22)
# Shape after subsample:  (24736, 22)
#
#  Sampling of 0.65 % of the original dataframe
#
# ----------YEAR 2023 DONE----------
#
# ----------STARTING YEAR 2022----------
# ...

# %%
df.to_csv('df_toulouse_dvf.csv', index=False, sep="|")

# %%
from google.colab import files
files.download("df_toulouse_dvf.csv")
